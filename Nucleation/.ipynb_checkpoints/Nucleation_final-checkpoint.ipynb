# %%
import cclib
from ase.thermochemistry import IdealGasThermo
from ase.thermochemistry import HarmonicThermo
from ase.io import read,write
import numpy as np
from numpy import array
import pandas as pd
from scipy.spatial import distance

SUB = str.maketrans("0123456789", "₀₁₂₃₄₅₆₇₈₉")

# %%
import pickle
import math
import cclib
from ase.io import read
from ase.thermochemistry import IdealGasThermo, HarmonicThermo

P = 101325  # Pressure in Pascal
# T_CVD = [298.15, 973.15, 1023.15, 1123.15, 1223.15, 1323.15]  # Temperature in K
T_CVD = [973.15, 1023.15, 1123.15, 1223.15]  # Temperature in K
ref_files = ['MoCO6', 'MoCO3', 'H2S', 'CO', 'H2']
type = ['nonlinear', 'nonlinear', 'nonlinear', 'linear', 'linear']
sym_num = [24, 1, 1, 1, 2]  # Rotational Symmetry number, Table 10.1, Cramer “Essentials of Computational Chemistry”
# cluster_files = ['25_MoS4H2', '33_Mo2S6H4', '43_Mo3S8H4', '53_Mo4S10H4', '69_Mo5S12', '79_Mo6S14', '89_Mo7S16', '99_Mo8S18',
#                  '109_Mo9S20', '121_Mo10S22']
cluster_files = ['MoS4H2', 'Mo2S6H4', 'Mo3S8H4', 'Mo4S10H4', 'Mo5S12', 'Mo6S14', 'Mo7S16', 'Mo8S18',
                 'Mo9S20']
init = "/home/chesagar/CVD_sagar/reacion_plotting/CVD-manuscript_data/Nucleation/gas-phase/"
fin = ".log"

G_ase_ref = {}
G_ase_cluster = {}
G_ase_cluster_harm = {}
cluster_size = {}
H2S_num_list = {}
count_H2_rem_list = {}

del_G_Ideal = {}
del_G_Harmonic = {}

del_G_Ideal_MoCO3 = {}
del_G_Harmonic_MoCO3 = {}

for j, temp in enumerate(T_CVD):
    G_ase_ref[temp] = {}
    G_ase_cluster[temp] = {}
    G_ase_cluster_harm[temp] = {}
    cluster_size[temp] = {}
    H2S_num_list[temp] = {}
    count_H2_rem_list[temp] = {}
    del_G_Ideal[temp] = {}
    del_G_Harmonic[temp] = {}
    del_G_Ideal_MoCO3[temp] = {}
    del_G_Harmonic_MoCO3[temp] = {}

    for i, ref_file in enumerate(ref_files):
        file_name = init + ref_file + fin
        parser = cclib.io.ccopen(file_name)
        data = parser.parse()
        with open(file_name) as reader:
            for line in reader.read().splitlines():
                if 'SCF Done' in line:
                    last_line = line
                    columns = last_line.split()
        E_au = float(columns[4])
        E_eV = E_au * 27.211324570273
        atoms_list = data.atomnos
        vib_freq = data.vibfreqs
        atoms = read(file_name)
        potE = E_eV
        vibs = vib_freq
        vib_energies = vibs / 8065.54429

        thermo = IdealGasThermo(vib_energies=vib_energies,
                                potentialenergy=potE,
                                atoms=atoms,
                                geometry=str(type[i]),
                                symmetrynumber=sym_num[i],
                                spin=0)

        G_ase_eV = thermo.get_gibbs_energy(temperature=temp, pressure=P)
        G_ase_au = G_ase_eV / 27.211324570273
        G_ase_ref[temp][ref_file] = G_ase_au

    for l, cluster_file in enumerate(cluster_files):
        file_name = init + cluster_file + fin
        parser = cclib.io.ccopen(file_name)
        data = parser.parse()
        atoms_list = data.atomnos
        A = [str(x) for x in atoms_list]
        count_Mo = f'{A.count("42")}'
        count_S = f'{A.count("16")}'
        count_H = f'{A.count("1")}'
        count_C = f'{A.count("6")}'
        Mol_formula = "Mo" + count_Mo + "S" + count_S + "H" + count_H + "C" + count_C + "O" + count_C
        count_H2_rem = (2 * int(count_S) - int(count_H)) / 2
        count_H2_rem_list[temp][cluster_file] = count_H2_rem
        cluster_size[temp][cluster_file] = int(count_Mo)
        H2S_num_list[temp][cluster_file] = int(count_S)

        with open(file_name) as reader:
            for line in reader.read().splitlines():
                if 'SCF Done' in line:
                    last_line = line
                    columns = last_line.split()
        E_au = float(columns[4])
        E_eV = E_au * 27.211324570273
        atoms_list = data.atomnos
        vib_freq = data.vibfreqs
        atoms = read(file_name)
        potE = E_eV
        vibs = vib_freq
        vib_energies = vibs / 8065.54429

        thermo = IdealGasThermo(vib_energies=vib_energies,
                                potentialenergy=potE,
                                atoms=atoms,
                                geometry='nonlinear',
                                symmetrynumber=1,
                                spin=0)

        G_ase_eV = thermo.get_gibbs_energy(temperature=temp, pressure=P)
        G_ase_au = G_ase_eV / 27.211324570273
        G_ase_cluster[temp][cluster_file] = G_ase_au

        thermo_harm = HarmonicThermo(vib_energies, potentialenergy=potE)
        G_ase_harm_eV = thermo_harm.get_helmholtz_energy(temperature=temp, verbose=True)
        G_ase_harm_au = G_ase_harm_eV / 27.211324570273
        G_ase_cluster_harm[temp][cluster_file] = G_ase_harm_au

    for i, cluster_file in enumerate(cluster_files):
        # Considering Mo(CO)6 and H2S as reactants
        del_G_rxn_Ideal = ((G_ase_cluster[temp][cluster_file] + 6 * cluster_size[temp][cluster_file] * G_ase_ref[temp]['CO'] +
                            count_H2_rem_list[temp][cluster_file] * G_ase_ref[temp]['H2']) -
                           (cluster_size[temp][cluster_file] * G_ase_ref[temp]['MoCO6'] +
                            H2S_num_list[temp][cluster_file] * G_ase_ref[temp]['H2S'])) * 627.507
        del_G_Ideal[temp][cluster_file] = del_G_rxn_Ideal
        
        del_G_rxn_harm = ((G_ase_cluster_harm[temp][cluster_file] + 6 * cluster_size[temp][cluster_file] * G_ase_ref[temp]['CO'] +
                           count_H2_rem_list[temp][cluster_file] * G_ase_ref[temp]['H2']) -
                          (cluster_size[temp][cluster_file] * G_ase_ref[temp]['MoCO6'] +
                           H2S_num_list[temp][cluster_file] * G_ase_ref[temp]['H2S'])) * 627.507
        del_G_Harmonic[temp][cluster_file] = del_G_rxn_harm
        
        # Considering Mo(CO)3 and H2S as reactants
        del_G_rxn_Ideal_MoCO3 = ((G_ase_cluster[temp][cluster_file] + 3 * cluster_size[temp][cluster_file] * G_ase_ref[temp]['CO'] +
                            count_H2_rem_list[temp][cluster_file] * G_ase_ref[temp]['H2']) -
                           (cluster_size[temp][cluster_file] * G_ase_ref[temp]['MoCO3'] +
                            H2S_num_list[temp][cluster_file] * G_ase_ref[temp]['H2S'])) * 627.507
        del_G_Ideal_MoCO3[temp][cluster_file] = del_G_rxn_Ideal_MoCO3
        
        del_G_rxn_harm_MoCO3 = ((G_ase_cluster_harm[temp][cluster_file] + 3 * cluster_size[temp][cluster_file] * G_ase_ref[temp]['CO'] +
                           count_H2_rem_list[temp][cluster_file] * G_ase_ref[temp]['H2']) -
                          (cluster_size[temp][cluster_file] * G_ase_ref[temp]['MoCO3'] +
                           H2S_num_list[temp][cluster_file] * G_ase_ref[temp]['H2S'])) * 627.507
        del_G_Harmonic_MoCO3[temp][cluster_file] = del_G_rxn_harm_MoCO3

# Save dictionaries to files
with open('del_G_Ideal.pkl', 'wb') as file:
    pickle.dump(del_G_Ideal, file)
    
with open('del_G_Ideal_MoCO3.pkl', 'wb') as file:
    pickle.dump(del_G_Ideal_MoCO3, file)

with open('del_G_Harmonic.pkl', 'wb') as file:
    pickle.dump(del_G_Harmonic, file)

with open('del_G_Harmonic_MoCO3.pkl', 'wb') as file:
    pickle.dump(del_G_Harmonic_MoCO3, file)
# Out:
# Enthalpy components at T = 973.15 K:
# ===============================
# E_pot             -20343.936 eV
# E_ZPE                  1.332 eV
# Cv_trans (0->T)        0.126 eV
# Cv_rot (0->T)          0.126 eV
# Cv_vib (0->T)          1.848 eV
# (C_v -> C_p)           0.084 eV
# -------------------------------
# H                 -20340.421 eV
# ===============================
#
# Entropy components at T = 973.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0021038 eV/K        2.047 eV
# S_rot              0.0012575 eV/K        1.224 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0047989 eV/K        4.670 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0081591 eV/K        7.940 eV
# =================================================
#
# Free energy components at T = 973.15 K and P = 101325.0 Pa:
# =======================
#     H     -20340.421 eV
#  -T*S         -7.940 eV
# -----------------------
#     G     -20348.361 eV
# =======================
# Enthalpy components at T = 973.15 K:
# ===============================
# E_pot             -11089.402 eV
# E_ZPE                  0.676 eV
# Cv_trans (0->T)        0.126 eV
# Cv_rot (0->T)          0.126 eV
# Cv_vib (0->T)          0.782 eV
# (C_v -> C_p)           0.084 eV
# -------------------------------
# H                 -11087.609 eV
# ===============================
#
# Entropy components at T = 973.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0020543 eV/K        1.999 eV
# S_rot              0.0014068 eV/K        1.369 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0018442 eV/K        1.795 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0053041 eV/K        5.162 eV
# =================================================
#
# Free energy components at T = 973.15 K and P = 101325.0 Pa:
# =======================
#     H     -11087.609 eV
#  -T*S         -5.162 eV
# -----------------------
#     G     -11092.771 eV
# =======================
# Enthalpy components at T = 973.15 K:
# ===============================
# E_pot             -10867.975 eV
# E_ZPE                  0.411 eV
# Cv_trans (0->T)        0.126 eV
# Cv_rot (0->T)          0.126 eV
# Cv_vib (0->T)          0.042 eV
# (C_v -> C_p)           0.084 eV
# -------------------------------
# H                 -10867.187 eV
# ===============================
#
# Entropy components at T = 973.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0018392 eV/K        1.790 eV
# S_rot              0.0007599 eV/K        0.739 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0000621 eV/K        0.060 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0026600 eV/K        2.589 eV
# =================================================
#
# Free energy components at T = 973.15 K and P = 101325.0 Pa:
# =======================
#     H     -10867.187 eV
#  -T*S         -2.589 eV
# -----------------------
#     G     -10869.775 eV
# =======================
# Enthalpy components at T = 973.15 K:
# ===============================
# E_pot              -3083.300 eV
# E_ZPE                  0.137 eV
# Cv_trans (0->T)        0.126 eV
# Cv_rot (0->T)          0.084 eV
# Cv_vib (0->T)          0.011 eV
# (C_v -> C_p)           0.084 eV
# -------------------------------
# H                  -3082.859 eV
# ===============================
#
# Entropy components at T = 973.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0018138 eV/K        1.765 eV
# S_rot              0.0005925 eV/K        0.577 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0000145 eV/K        0.014 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0024197 eV/K        2.355 eV
# =================================================
#
# Free energy components at T = 973.15 K and P = 101325.0 Pa:
# =======================
#     H      -3082.859 eV
#  -T*S         -2.355 eV
# -----------------------
#     G      -3085.214 eV
# =======================
# Enthalpy components at T = 973.15 K:
# ===============================
# E_pot                -32.070 eV
# E_ZPE                  0.277 eV
# Cv_trans (0->T)        0.126 eV
# Cv_rot (0->T)          0.084 eV
# Cv_vib (0->T)          0.001 eV
# (C_v -> C_p)           0.084 eV
# -------------------------------
# H                    -31.498 eV
# ===============================
#
# Entropy components at T = 973.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0014737 eV/K        1.434 eV
# S_rot              0.0002342 eV/K        0.228 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0000009 eV/K        0.001 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0017077 eV/K        1.662 eV
# =================================================
#
# Free energy components at T = 973.15 K and P = 101325.0 Pa:
# =======================
#     H        -31.498 eV
#  -T*S         -1.662 eV
# -----------------------
#     G        -33.160 eV
# =======================
# Enthalpy components at T = 973.15 K:
# ===============================
# E_pot             -45214.719 eV
# E_ZPE                  0.608 eV
# Cv_trans (0->T)        0.126 eV
# Cv_rot (0->T)          0.126 eV
# Cv_vib (0->T)          0.857 eV
# (C_v -> C_p)           0.084 eV
# -------------------------------
# H                 -45212.919 eV
# ===============================
#
# Entropy components at T = 973.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0020838 eV/K        2.028 eV
# S_rot              0.0014408 eV/K        1.402 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0021113 eV/K        2.055 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0056348 eV/K        5.483 eV
# =================================================
#
# Free energy components at T = 973.15 K and P = 101325.0 Pa:
# =======================
#     H     -45212.919 eV
#  -T*S         -5.483 eV
# -----------------------
#     G     -45218.402 eV
# =======================
# Internal energy components at T = 973.15 K:
# ===============================
# E_pot             -45214.719 eV
# E_ZPE                  0.608 eV
# Cv_harm (0->T)         0.857 eV
# -------------------------------
# U                 -45213.254 eV
# ===============================
#
# Entropy components at T = 973.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0021113 eV/K        2.055 eV
# -------------------------------------------------
# S                  0.0021113 eV/K        2.055 eV
# =================================================
#
# Free energy components at T = 973.15 K:
# =======================
#     U     -45213.254 eV
#  -T*S         -2.055 eV
# -----------------------
#     F     -45215.309 eV
# =======================
# /home/chesagar/.local/lib/python3.8/site-packages/cclib/parser/utils.py:182: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   r, _ = scipy.spatial.transform.Rotation.align_vectors(b_, a_)
# Enthalpy components at T = 973.15 K:
# ===============================
# E_pot             -68758.089 eV
# E_ZPE                  1.122 eV
# Cv_trans (0->T)        0.126 eV
# Cv_rot (0->T)          0.126 eV
# Cv_vib (0->T)          1.783 eV
# (C_v -> C_p)           0.084 eV
# -------------------------------
# H                 -68754.849 eV
# ===============================
#
# Entropy components at T = 973.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0021537 eV/K        2.096 eV
# S_rot              0.0015782 eV/K        1.536 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0047923 eV/K        4.664 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0085230 eV/K        8.294 eV
# =================================================
#
# Free energy components at T = 973.15 K and P = 101325.0 Pa:
# =======================
#     H     -68754.849 eV
#  -T*S         -8.294 eV
# -----------------------
#     G     -68763.143 eV
# =======================
# Internal energy components at T = 973.15 K:
# ===============================
# E_pot             -68758.089 eV
# E_ZPE                  1.122 eV
# Cv_harm (0->T)         1.783 eV
# -------------------------------
# U                 -68755.184 eV
# ===============================
#
# Entropy components at T = 973.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0047923 eV/K        4.664 eV
# -------------------------------------------------
# S                  0.0047923 eV/K        4.664 eV
# =================================================
#
# Free energy components at T = 973.15 K:
# =======================
#     U     -68755.184 eV
#  -T*S         -4.664 eV
# -----------------------
#     F     -68759.848 eV
# =======================
# Enthalpy components at T = 973.15 K:
# ===============================
# E_pot             -92270.117 eV
# E_ZPE                  1.300 eV
# Cv_trans (0->T)        0.126 eV
# Cv_rot (0->T)          0.126 eV
# Cv_vib (0->T)          2.385 eV
# (C_v -> C_p)           0.084 eV
# -------------------------------
# H                 -92266.096 eV
# ===============================
#
# Entropy components at T = 973.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0021983 eV/K        2.139 eV
# S_rot              0.0016482 eV/K        1.604 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0062680 eV/K        6.100 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0101133 eV/K        9.842 eV
# =================================================
#
# Free energy components at T = 973.15 K and P = 101325.0 Pa:
# =======================
#     H     -92266.096 eV
#  -T*S         -9.842 eV
# -----------------------
#     G     -92275.938 eV
# =======================
# Internal energy components at T = 973.15 K:
# ===============================
# E_pot             -92270.117 eV
# E_ZPE                  1.300 eV
# Cv_harm (0->T)         2.385 eV
# -------------------------------
# U                 -92266.432 eV
# ===============================
#
# Entropy components at T = 973.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0062680 eV/K        6.100 eV
# -------------------------------------------------
# S                  0.0062680 eV/K        6.100 eV
# =================================================
#
# Free energy components at T = 973.15 K:
# =======================
#     U     -92266.432 eV
#  -T*S         -6.100 eV
# -----------------------
#     F     -92272.532 eV
# =======================
# Enthalpy components at T = 973.15 K:
# ===============================
# E_pot            -115781.310 eV
# E_ZPE                  1.464 eV
# Cv_trans (0->T)        0.126 eV
# Cv_rot (0->T)          0.126 eV
# Cv_vib (0->T)          2.992 eV
# (C_v -> C_p)           0.084 eV
# -------------------------------
# H                -115776.518 eV
# ===============================
#
# Entropy components at T = 973.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0022314 eV/K        2.171 eV
# S_rot              0.0017095 eV/K        1.664 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0078740 eV/K        7.663 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0118138 eV/K       11.497 eV
# =================================================
#
# Free energy components at T = 973.15 K and P = 101325.0 Pa:
# =======================
#     H    -115776.518 eV
#  -T*S        -11.497 eV
# -----------------------
#     G    -115788.015 eV
# =======================
# Internal energy components at T = 973.15 K:
# ===============================
# E_pot            -115781.310 eV
# E_ZPE                  1.464 eV
# Cv_harm (0->T)         2.992 eV
# -------------------------------
# U                -115776.854 eV
# ===============================
#
# Entropy components at T = 973.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0078740 eV/K        7.663 eV
# -------------------------------------------------
# S                  0.0078740 eV/K        7.663 eV
# =================================================
#
# Free energy components at T = 973.15 K:
# =======================
#     U    -115776.854 eV
#  -T*S         -7.663 eV
# -----------------------
#     F    -115784.517 eV
# =======================
# Enthalpy components at T = 973.15 K:
# ===============================
# E_pot            -139227.079 eV
# E_ZPE                  0.694 eV
# Cv_trans (0->T)        0.126 eV
# Cv_rot (0->T)          0.126 eV
# Cv_vib (0->T)          3.138 eV
# (C_v -> C_p)           0.084 eV
# -------------------------------
# H                -139222.911 eV
# ===============================
#
# Entropy components at T = 973.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0022571 eV/K        2.197 eV
# S_rot              0.0017692 eV/K        1.722 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0087664 eV/K        8.531 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0127916 eV/K       12.448 eV
# =================================================
#
# Free energy components at T = 973.15 K and P = 101325.0 Pa:
# =======================
#     H    -139222.911 eV
#  -T*S        -12.448 eV
# -----------------------
#     G    -139235.360 eV
# =======================
# Internal energy components at T = 973.15 K:
# ===============================
# E_pot            -139227.079 eV
# E_ZPE                  0.694 eV
# Cv_harm (0->T)         3.138 eV
# -------------------------------
# U                -139223.247 eV
# ===============================
#
# Entropy components at T = 973.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0087664 eV/K        8.531 eV
# -------------------------------------------------
# S                  0.0087664 eV/K        8.531 eV
# =================================================
#
# Free energy components at T = 973.15 K:
# =======================
#     U    -139223.247 eV
#  -T*S         -8.531 eV
# -----------------------
#     F    -139231.778 eV
# =======================
# Enthalpy components at T = 973.15 K:
# ===============================
# E_pot            -162739.393 eV
# E_ZPE                  0.835 eV
# Cv_trans (0->T)        0.126 eV
# Cv_rot (0->T)          0.126 eV
# Cv_vib (0->T)          3.764 eV
# (C_v -> C_p)           0.084 eV
# -------------------------------
# H                -162734.459 eV
# ===============================
#
# Entropy components at T = 973.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0022791 eV/K        2.218 eV
# S_rot              0.0018111 eV/K        1.762 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0104643 eV/K       10.183 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0145533 eV/K       14.163 eV
# =================================================
#
# Free energy components at T = 973.15 K and P = 101325.0 Pa:
# =======================
#     H    -162734.459 eV
#  -T*S        -14.163 eV
# -----------------------
#     G    -162748.621 eV
# =======================
# Internal energy components at T = 973.15 K:
# ===============================
# E_pot            -162739.393 eV
# E_ZPE                  0.835 eV
# Cv_harm (0->T)         3.764 eV
# -------------------------------
# U                -162734.794 eV
# ===============================
#
# Entropy components at T = 973.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0104643 eV/K       10.183 eV
# -------------------------------------------------
# S                  0.0104643 eV/K       10.183 eV
# =================================================
#
# Free energy components at T = 973.15 K:
# =======================
#     U    -162734.794 eV
#  -T*S        -10.183 eV
# -----------------------
#     F    -162744.978 eV
# =======================
# Enthalpy components at T = 973.15 K:
# ===============================
# E_pot            -186251.475 eV
# E_ZPE                  0.975 eV
# Cv_trans (0->T)        0.126 eV
# Cv_rot (0->T)          0.126 eV
# Cv_vib (0->T)          4.390 eV
# (C_v -> C_p)           0.084 eV
# -------------------------------
# H                -186245.775 eV
# ===============================
#
# Entropy components at T = 973.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0022978 eV/K        2.236 eV
# S_rot              0.0018505 eV/K        1.801 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0121498 eV/K       11.824 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0162971 eV/K       15.859 eV
# =================================================
#
# Free energy components at T = 973.15 K and P = 101325.0 Pa:
# =======================
#     H    -186245.775 eV
#  -T*S        -15.859 eV
# -----------------------
#     G    -186261.634 eV
# =======================
# Internal energy components at T = 973.15 K:
# ===============================
# E_pot            -186251.475 eV
# E_ZPE                  0.975 eV
# Cv_harm (0->T)         4.390 eV
# -------------------------------
# U                -186246.110 eV
# ===============================
#
# Entropy components at T = 973.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0121498 eV/K       11.824 eV
# -------------------------------------------------
# S                  0.0121498 eV/K       11.824 eV
# =================================================
#
# Free energy components at T = 973.15 K:
# =======================
#     U    -186246.110 eV
#  -T*S        -11.824 eV
# -----------------------
#     F    -186257.934 eV
# =======================
# Enthalpy components at T = 973.15 K:
# ===============================
# E_pot            -209763.814 eV
# E_ZPE                  1.120 eV
# Cv_trans (0->T)        0.126 eV
# Cv_rot (0->T)          0.126 eV
# Cv_vib (0->T)          5.012 eV
# (C_v -> C_p)           0.084 eV
# -------------------------------
# H                -209757.347 eV
# ===============================
#
# Entropy components at T = 973.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0023142 eV/K        2.252 eV
# S_rot              0.0018792 eV/K        1.829 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0137580 eV/K       13.389 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0179502 eV/K       17.468 eV
# =================================================
#
# Free energy components at T = 973.15 K and P = 101325.0 Pa:
# =======================
#     H    -209757.347 eV
#  -T*S        -17.468 eV
# -----------------------
#     G    -209774.816 eV
# =======================
# Internal energy components at T = 973.15 K:
# ===============================
# E_pot            -209763.814 eV
# E_ZPE                  1.120 eV
# Cv_harm (0->T)         5.012 eV
# -------------------------------
# U                -209757.683 eV
# ===============================
#
# Entropy components at T = 973.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0137580 eV/K       13.389 eV
# -------------------------------------------------
# S                  0.0137580 eV/K       13.389 eV
# =================================================
#
# Free energy components at T = 973.15 K:
# =======================
#     U    -209757.683 eV
#  -T*S        -13.389 eV
# -----------------------
#     F    -209771.071 eV
# =======================
# Enthalpy components at T = 973.15 K:
# ===============================
# E_pot            -233275.146 eV
# E_ZPE                  1.254 eV
# Cv_trans (0->T)        0.126 eV
# Cv_rot (0->T)          0.126 eV
# Cv_vib (0->T)          5.644 eV
# (C_v -> C_p)           0.084 eV
# -------------------------------
# H                -233267.913 eV
# ===============================
#
# Entropy components at T = 973.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0023288 eV/K        2.266 eV
# S_rot              0.0019034 eV/K        1.852 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0156262 eV/K       15.207 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0198572 eV/K       19.324 eV
# =================================================
#
# Free energy components at T = 973.15 K and P = 101325.0 Pa:
# =======================
#     H    -233267.913 eV
#  -T*S        -19.324 eV
# -----------------------
#     G    -233287.237 eV
# =======================
# Internal energy components at T = 973.15 K:
# ===============================
# E_pot            -233275.146 eV
# E_ZPE                  1.254 eV
# Cv_harm (0->T)         5.644 eV
# -------------------------------
# U                -233268.249 eV
# ===============================
#
# Entropy components at T = 973.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0156262 eV/K       15.207 eV
# -------------------------------------------------
# S                  0.0156262 eV/K       15.207 eV
# =================================================
#
# Free energy components at T = 973.15 K:
# =======================
#     U    -233268.249 eV
#  -T*S        -15.207 eV
# -----------------------
#     F    -233283.455 eV
# =======================
# Enthalpy components at T = 1023.15 K:
# ===============================
# E_pot             -20343.936 eV
# E_ZPE                  1.332 eV
# Cv_trans (0->T)        0.132 eV
# Cv_rot (0->T)          0.132 eV
# Cv_vib (0->T)          1.974 eV
# (C_v -> C_p)           0.088 eV
# -------------------------------
# H                 -20340.277 eV
# ===============================
#
# Entropy components at T = 1023.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0021146 eV/K        2.164 eV
# S_rot              0.0012640 eV/K        1.293 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0049252 eV/K        5.039 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0083027 eV/K        8.495 eV
# =================================================
#
# Free energy components at T = 1023.15 K and P = 101325.0 Pa:
# =======================
#     H     -20340.277 eV
#  -T*S         -8.495 eV
# -----------------------
#     G     -20348.772 eV
# =======================
# Enthalpy components at T = 1023.15 K:
# ===============================
# E_pot             -11089.402 eV
# E_ZPE                  0.676 eV
# Cv_trans (0->T)        0.132 eV
# Cv_rot (0->T)          0.132 eV
# Cv_vib (0->T)          0.838 eV
# (C_v -> C_p)           0.088 eV
# -------------------------------
# H                 -11087.535 eV
# ===============================
#
# Entropy components at T = 1023.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0020651 eV/K        2.113 eV
# S_rot              0.0014133 eV/K        1.446 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0019009 eV/K        1.945 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0053781 eV/K        5.503 eV
# =================================================
#
# Free energy components at T = 1023.15 K and P = 101325.0 Pa:
# =======================
#     H     -11087.535 eV
#  -T*S         -5.503 eV
# -----------------------
#     G     -11093.038 eV
# =======================
# Enthalpy components at T = 1023.15 K:
# ===============================
# E_pot             -10867.975 eV
# E_ZPE                  0.411 eV
# Cv_trans (0->T)        0.132 eV
# Cv_rot (0->T)          0.132 eV
# Cv_vib (0->T)          0.048 eV
# (C_v -> C_p)           0.088 eV
# -------------------------------
# H                 -10867.163 eV
# ===============================
#
# Entropy components at T = 1023.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0018499 eV/K        1.893 eV
# S_rot              0.0007664 eV/K        0.784 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0000682 eV/K        0.070 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0026834 eV/K        2.746 eV
# =================================================
#
# Free energy components at T = 1023.15 K and P = 101325.0 Pa:
# =======================
#     H     -10867.163 eV
#  -T*S         -2.746 eV
# -----------------------
#     G     -10869.909 eV
# =======================
# Enthalpy components at T = 1023.15 K:
# ===============================
# E_pot              -3083.300 eV
# E_ZPE                  0.137 eV
# Cv_trans (0->T)        0.132 eV
# Cv_rot (0->T)          0.088 eV
# Cv_vib (0->T)          0.013 eV
# (C_v -> C_p)           0.088 eV
# -------------------------------
# H                  -3082.842 eV
# ===============================
#
# Entropy components at T = 1023.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0018246 eV/K        1.867 eV
# S_rot              0.0005969 eV/K        0.611 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0000165 eV/K        0.017 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0024368 eV/K        2.493 eV
# =================================================
#
# Free energy components at T = 1023.15 K and P = 101325.0 Pa:
# =======================
#     H      -3082.842 eV
#  -T*S         -2.493 eV
# -----------------------
#     G      -3085.335 eV
# =======================
# Enthalpy components at T = 1023.15 K:
# ===============================
# E_pot                -32.070 eV
# E_ZPE                  0.277 eV
# Cv_trans (0->T)        0.132 eV
# Cv_rot (0->T)          0.088 eV
# Cv_vib (0->T)          0.001 eV
# (C_v -> C_p)           0.088 eV
# -------------------------------
# H                    -31.483 eV
# ===============================
#
# Entropy components at T = 1023.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0014845 eV/K        1.519 eV
# S_rot              0.0002385 eV/K        0.244 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0000012 eV/K        0.001 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0017230 eV/K        1.763 eV
# =================================================
#
# Free energy components at T = 1023.15 K and P = 101325.0 Pa:
# =======================
#     H        -31.483 eV
#  -T*S         -1.763 eV
# -----------------------
#     G        -33.246 eV
# =======================
# Enthalpy components at T = 1023.15 K:
# ===============================
# E_pot             -45214.719 eV
# E_ZPE                  0.608 eV
# Cv_trans (0->T)        0.132 eV
# Cv_rot (0->T)          0.132 eV
# Cv_vib (0->T)          0.914 eV
# (C_v -> C_p)           0.088 eV
# -------------------------------
# H                 -45212.844 eV
# ===============================
#
# Entropy components at T = 1023.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0020946 eV/K        2.143 eV
# S_rot              0.0014473 eV/K        1.481 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0021688 eV/K        2.219 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0057096 eV/K        5.842 eV
# =================================================
#
# Free energy components at T = 1023.15 K and P = 101325.0 Pa:
# =======================
#     H     -45212.844 eV
#  -T*S         -5.842 eV
# -----------------------
#     G     -45218.686 eV
# =======================
# Internal energy components at T = 1023.15 K:
# ===============================
# E_pot             -45214.719 eV
# E_ZPE                  0.608 eV
# Cv_harm (0->T)         0.914 eV
# -------------------------------
# U                 -45213.197 eV
# ===============================
#
# Entropy components at T = 1023.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0021688 eV/K        2.219 eV
# -------------------------------------------------
# S                  0.0021688 eV/K        2.219 eV
# =================================================
#
# Free energy components at T = 1023.15 K:
# =======================
#     U     -45213.197 eV
#  -T*S         -2.219 eV
# -----------------------
#     F     -45215.416 eV
# =======================
# Enthalpy components at T = 1023.15 K:
# ===============================
# E_pot             -68758.089 eV
# E_ZPE                  1.122 eV
# Cv_trans (0->T)        0.132 eV
# Cv_rot (0->T)          0.132 eV
# Cv_vib (0->T)          1.898 eV
# (C_v -> C_p)           0.088 eV
# -------------------------------
# H                 -68754.716 eV
# ===============================
#
# Entropy components at T = 1023.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0021645 eV/K        2.215 eV
# S_rot              0.0015846 eV/K        1.621 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0049081 eV/K        5.022 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0086561 eV/K        8.856 eV
# =================================================
#
# Free energy components at T = 1023.15 K and P = 101325.0 Pa:
# =======================
#     H     -68754.716 eV
#  -T*S         -8.856 eV
# -----------------------
#     G     -68763.572 eV
# =======================
# Internal energy components at T = 1023.15 K:
# ===============================
# E_pot             -68758.089 eV
# E_ZPE                  1.122 eV
# Cv_harm (0->T)         1.898 eV
# -------------------------------
# U                 -68755.069 eV
# ===============================
#
# Entropy components at T = 1023.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0049081 eV/K        5.022 eV
# -------------------------------------------------
# S                  0.0049081 eV/K        5.022 eV
# =================================================
#
# Free energy components at T = 1023.15 K:
# =======================
#     U     -68755.069 eV
#  -T*S         -5.022 eV
# -----------------------
#     F     -68760.090 eV
# =======================
# Enthalpy components at T = 1023.15 K:
# ===============================
# E_pot             -92270.117 eV
# E_ZPE                  1.300 eV
# Cv_trans (0->T)        0.132 eV
# Cv_rot (0->T)          0.132 eV
# Cv_vib (0->T)          2.539 eV
# (C_v -> C_p)           0.088 eV
# -------------------------------
# H                 -92265.926 eV
# ===============================
#
# Entropy components at T = 1023.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0022091 eV/K        2.260 eV
# S_rot              0.0016547 eV/K        1.693 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0064218 eV/K        6.570 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0102844 eV/K       10.522 eV
# =================================================
#
# Free energy components at T = 1023.15 K and P = 101325.0 Pa:
# =======================
#     H     -92265.926 eV
#  -T*S        -10.522 eV
# -----------------------
#     G     -92276.448 eV
# =======================
# Internal energy components at T = 1023.15 K:
# ===============================
# E_pot             -92270.117 eV
# E_ZPE                  1.300 eV
# Cv_harm (0->T)         2.539 eV
# -------------------------------
# U                 -92266.278 eV
# ===============================
#
# Entropy components at T = 1023.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0064218 eV/K        6.570 eV
# -------------------------------------------------
# S                  0.0064218 eV/K        6.570 eV
# =================================================
#
# Free energy components at T = 1023.15 K:
# =======================
#     U     -92266.278 eV
#  -T*S         -6.570 eV
# -----------------------
#     F     -92272.849 eV
# =======================
# Enthalpy components at T = 1023.15 K:
# ===============================
# E_pot            -115781.310 eV
# E_ZPE                  1.464 eV
# Cv_trans (0->T)        0.132 eV
# Cv_rot (0->T)          0.132 eV
# Cv_vib (0->T)          3.184 eV
# (C_v -> C_p)           0.088 eV
# -------------------------------
# H                -115776.310 eV
# ===============================
#
# Entropy components at T = 1023.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0022422 eV/K        2.294 eV
# S_rot              0.0017160 eV/K        1.756 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0080659 eV/K        8.253 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0120229 eV/K       12.301 eV
# =================================================
#
# Free energy components at T = 1023.15 K and P = 101325.0 Pa:
# =======================
#     H    -115776.310 eV
#  -T*S        -12.301 eV
# -----------------------
#     G    -115788.611 eV
# =======================
# Internal energy components at T = 1023.15 K:
# ===============================
# E_pot            -115781.310 eV
# E_ZPE                  1.464 eV
# Cv_harm (0->T)         3.184 eV
# -------------------------------
# U                -115776.662 eV
# ===============================
#
# Entropy components at T = 1023.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0080659 eV/K        8.253 eV
# -------------------------------------------------
# S                  0.0080659 eV/K        8.253 eV
# =================================================
#
# Free energy components at T = 1023.15 K:
# =======================
#     U    -115776.662 eV
#  -T*S         -8.253 eV
# -----------------------
#     F    -115784.915 eV
# =======================
# Enthalpy components at T = 1023.15 K:
# ===============================
# E_pot            -139227.079 eV
# E_ZPE                  0.694 eV
# Cv_trans (0->T)        0.132 eV
# Cv_rot (0->T)          0.132 eV
# Cv_vib (0->T)          3.329 eV
# (C_v -> C_p)           0.088 eV
# -------------------------------
# H                -139222.703 eV
# ===============================
#
# Entropy components at T = 1023.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0022679 eV/K        2.320 eV
# S_rot              0.0017757 eV/K        1.817 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0089578 eV/K        9.165 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0130003 eV/K       13.301 eV
# =================================================
#
# Free energy components at T = 1023.15 K and P = 101325.0 Pa:
# =======================
#     H    -139222.703 eV
#  -T*S        -13.301 eV
# -----------------------
#     G    -139236.004 eV
# =======================
# Internal energy components at T = 1023.15 K:
# ===============================
# E_pot            -139227.079 eV
# E_ZPE                  0.694 eV
# Cv_harm (0->T)         3.329 eV
# -------------------------------
# U                -139223.056 eV
# ===============================
#
# Entropy components at T = 1023.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0089578 eV/K        9.165 eV
# -------------------------------------------------
# S                  0.0089578 eV/K        9.165 eV
# =================================================
#
# Free energy components at T = 1023.15 K:
# =======================
#     U    -139223.056 eV
#  -T*S         -9.165 eV
# -----------------------
#     F    -139232.221 eV
# =======================
# Enthalpy components at T = 1023.15 K:
# ===============================
# E_pot            -162739.393 eV
# E_ZPE                  0.835 eV
# Cv_trans (0->T)        0.132 eV
# Cv_rot (0->T)          0.132 eV
# Cv_vib (0->T)          3.993 eV
# (C_v -> C_p)           0.088 eV
# -------------------------------
# H                -162734.212 eV
# ===============================
#
# Entropy components at T = 1023.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0022899 eV/K        2.343 eV
# S_rot              0.0018175 eV/K        1.860 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0106940 eV/K       10.942 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0148003 eV/K       15.143 eV
# =================================================
#
# Free energy components at T = 1023.15 K and P = 101325.0 Pa:
# =======================
#     H    -162734.212 eV
#  -T*S        -15.143 eV
# -----------------------
#     G    -162749.355 eV
# =======================
# Internal energy components at T = 1023.15 K:
# ===============================
# E_pot            -162739.393 eV
# E_ZPE                  0.835 eV
# Cv_harm (0->T)         3.993 eV
# -------------------------------
# U                -162734.565 eV
# ===============================
#
# Entropy components at T = 1023.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0106940 eV/K       10.942 eV
# -------------------------------------------------
# S                  0.0106940 eV/K       10.942 eV
# =================================================
#
# Free energy components at T = 1023.15 K:
# =======================
#     U    -162734.565 eV
#  -T*S        -10.942 eV
# -----------------------
#     F    -162745.507 eV
# =======================
# Enthalpy components at T = 1023.15 K:
# ===============================
# E_pot            -186251.475 eV
# E_ZPE                  0.975 eV
# Cv_trans (0->T)        0.132 eV
# Cv_rot (0->T)          0.132 eV
# Cv_vib (0->T)          4.657 eV
# (C_v -> C_p)           0.088 eV
# -------------------------------
# H                -186245.490 eV
# ===============================
#
# Entropy components at T = 1023.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0023086 eV/K        2.362 eV
# S_rot              0.0018570 eV/K        1.900 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0124179 eV/K       12.705 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0165824 eV/K       16.966 eV
# =================================================
#
# Free energy components at T = 1023.15 K and P = 101325.0 Pa:
# =======================
#     H    -186245.490 eV
#  -T*S        -16.966 eV
# -----------------------
#     G    -186262.456 eV
# =======================
# Internal energy components at T = 1023.15 K:
# ===============================
# E_pot            -186251.475 eV
# E_ZPE                  0.975 eV
# Cv_harm (0->T)         4.657 eV
# -------------------------------
# U                -186245.842 eV
# ===============================
#
# Entropy components at T = 1023.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0124179 eV/K       12.705 eV
# -------------------------------------------------
# S                  0.0124179 eV/K       12.705 eV
# =================================================
#
# Free energy components at T = 1023.15 K:
# =======================
#     U    -186245.842 eV
#  -T*S        -12.705 eV
# -----------------------
#     F    -186258.548 eV
# =======================
# Enthalpy components at T = 1023.15 K:
# ===============================
# E_pot            -209763.814 eV
# E_ZPE                  1.120 eV
# Cv_trans (0->T)        0.132 eV
# Cv_rot (0->T)          0.132 eV
# Cv_vib (0->T)          5.317 eV
# (C_v -> C_p)           0.088 eV
# -------------------------------
# H                -209757.024 eV
# ===============================
#
# Entropy components at T = 1023.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0023250 eV/K        2.379 eV
# S_rot              0.0018856 eV/K        1.929 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0140643 eV/K       14.390 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0182738 eV/K       18.697 eV
# =================================================
#
# Free energy components at T = 1023.15 K and P = 101325.0 Pa:
# =======================
#     H    -209757.024 eV
#  -T*S        -18.697 eV
# -----------------------
#     G    -209775.721 eV
# =======================
# Internal energy components at T = 1023.15 K:
# ===============================
# E_pot            -209763.814 eV
# E_ZPE                  1.120 eV
# Cv_harm (0->T)         5.317 eV
# -------------------------------
# U                -209757.377 eV
# ===============================
#
# Entropy components at T = 1023.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0140643 eV/K       14.390 eV
# -------------------------------------------------
# S                  0.0140643 eV/K       14.390 eV
# =================================================
#
# Free energy components at T = 1023.15 K:
# =======================
#     U    -209757.377 eV
#  -T*S        -14.390 eV
# -----------------------
#     F    -209771.767 eV
# =======================
# Enthalpy components at T = 1023.15 K:
# ===============================
# E_pot            -233275.146 eV
# E_ZPE                  1.254 eV
# Cv_trans (0->T)        0.132 eV
# Cv_rot (0->T)          0.132 eV
# Cv_vib (0->T)          5.987 eV
# (C_v -> C_p)           0.088 eV
# -------------------------------
# H                -233267.552 eV
# ===============================
#
# Entropy components at T = 1023.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0023396 eV/K        2.394 eV
# S_rot              0.0019099 eV/K        1.954 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0159708 eV/K       16.341 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0202191 eV/K       20.687 eV
# =================================================
#
# Free energy components at T = 1023.15 K and P = 101325.0 Pa:
# =======================
#     H    -233267.552 eV
#  -T*S        -20.687 eV
# -----------------------
#     G    -233288.239 eV
# =======================
# Internal energy components at T = 1023.15 K:
# ===============================
# E_pot            -233275.146 eV
# E_ZPE                  1.254 eV
# Cv_harm (0->T)         5.987 eV
# -------------------------------
# U                -233267.905 eV
# ===============================
#
# Entropy components at T = 1023.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0159708 eV/K       16.341 eV
# -------------------------------------------------
# S                  0.0159708 eV/K       16.341 eV
# =================================================
#
# Free energy components at T = 1023.15 K:
# =======================
#     U    -233267.905 eV
#  -T*S        -16.341 eV
# -----------------------
#     F    -233284.245 eV
# =======================
# Enthalpy components at T = 1123.15 K:
# ===============================
# E_pot             -20343.936 eV
# E_ZPE                  1.332 eV
# Cv_trans (0->T)        0.145 eV
# Cv_rot (0->T)          0.145 eV
# Cv_vib (0->T)          2.229 eV
# (C_v -> C_p)           0.097 eV
# -------------------------------
# H                 -20339.988 eV
# ===============================
#
# Entropy components at T = 1123.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0021347 eV/K        2.398 eV
# S_rot              0.0012761 eV/K        1.433 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0051633 eV/K        5.799 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0085730 eV/K        9.629 eV
# =================================================
#
# Free energy components at T = 1123.15 K and P = 101325.0 Pa:
# =======================
#     H     -20339.988 eV
#  -T*S         -9.629 eV
# -----------------------
#     G     -20349.616 eV
# =======================
# Enthalpy components at T = 1123.15 K:
# ===============================
# E_pot             -11089.402 eV
# E_ZPE                  0.676 eV
# Cv_trans (0->T)        0.145 eV
# Cv_rot (0->T)          0.145 eV
# Cv_vib (0->T)          0.953 eV
# (C_v -> C_p)           0.097 eV
# -------------------------------
# H                 -11087.386 eV
# ===============================
#
# Entropy components at T = 1123.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0020852 eV/K        2.342 eV
# S_rot              0.0014253 eV/K        1.601 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0020080 eV/K        2.255 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0055174 eV/K        6.197 eV
# =================================================
#
# Free energy components at T = 1123.15 K and P = 101325.0 Pa:
# =======================
#     H     -11087.386 eV
#  -T*S         -6.197 eV
# -----------------------
#     G     -11093.583 eV
# =======================
# Enthalpy components at T = 1123.15 K:
# ...
# E_pot             -45214.719 eV
# E_ZPE                  0.608 eV
# Cv_harm (0->T)         1.147 eV
# -------------------------------
# U                 -45212.964 eV
# ===============================
#
# Entropy components at T = 1223.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0023771 eV/K        2.908 eV
# -------------------------------------------------
# S                  0.0023771 eV/K        2.908 eV
# =================================================
#
# Free energy components at T = 1223.15 K:
# =======================
#     U     -45212.964 eV
#  -T*S         -2.908 eV
# -----------------------
#     F     -45215.871 eV
# =======================
# Enthalpy components at T = 1223.15 K:
# ===============================
# E_pot             -68758.089 eV
# E_ZPE                  1.122 eV
# Cv_trans (0->T)        0.158 eV
# Cv_rot (0->T)          0.158 eV
# Cv_vib (0->T)          2.368 eV
# (C_v -> C_p)           0.105 eV
# -------------------------------
# H                 -68754.177 eV
# ===============================
#
# Entropy components at T = 1223.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0022029 eV/K        2.695 eV
# S_rot              0.0016077 eV/K        1.966 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0053274 eV/K        6.516 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0091369 eV/K       11.176 eV
# =================================================
#
# Free energy components at T = 1223.15 K and P = 101325.0 Pa:
# =======================
#     H     -68754.177 eV
#  -T*S        -11.176 eV
# -----------------------
#     G     -68765.353 eV
# =======================
# Internal energy components at T = 1223.15 K:
# ===============================
# E_pot             -68758.089 eV
# E_ZPE                  1.122 eV
# Cv_harm (0->T)         2.368 eV
# -------------------------------
# U                 -68754.599 eV
# ===============================
#
# Entropy components at T = 1223.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0053274 eV/K        6.516 eV
# -------------------------------------------------
# S                  0.0053274 eV/K        6.516 eV
# =================================================
#
# Free energy components at T = 1223.15 K:
# =======================
#     U     -68754.599 eV
#  -T*S         -6.516 eV
# -----------------------
#     F     -68761.115 eV
# =======================
# Enthalpy components at T = 1223.15 K:
# ===============================
# E_pot             -92270.117 eV
# E_ZPE                  1.300 eV
# Cv_trans (0->T)        0.158 eV
# Cv_rot (0->T)          0.158 eV
# Cv_vib (0->T)          3.161 eV
# (C_v -> C_p)           0.105 eV
# -------------------------------
# H                 -92265.235 eV
# ===============================
#
# Entropy components at T = 1223.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0022475 eV/K        2.749 eV
# S_rot              0.0016778 eV/K        2.052 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0069766 eV/K        8.533 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0109008 eV/K       13.333 eV
# =================================================
#
# Free energy components at T = 1223.15 K and P = 101325.0 Pa:
# =======================
#     H     -92265.235 eV
#  -T*S        -13.333 eV
# -----------------------
#     G     -92278.568 eV
# =======================
# Internal energy components at T = 1223.15 K:
# ===============================
# E_pot             -92270.117 eV
# E_ZPE                  1.300 eV
# Cv_harm (0->T)         3.161 eV
# -------------------------------
# U                 -92265.657 eV
# ===============================
#
# Entropy components at T = 1223.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0069766 eV/K        8.533 eV
# -------------------------------------------------
# S                  0.0069766 eV/K        8.533 eV
# =================================================
#
# Free energy components at T = 1223.15 K:
# =======================
#     U     -92265.657 eV
#  -T*S         -8.533 eV
# -----------------------
#     F     -92274.190 eV
# =======================
# Enthalpy components at T = 1223.15 K:
# ===============================
# E_pot            -115781.310 eV
# E_ZPE                  1.464 eV
# Cv_trans (0->T)        0.158 eV
# Cv_rot (0->T)          0.158 eV
# Cv_vib (0->T)          3.958 eV
# (C_v -> C_p)           0.105 eV
# -------------------------------
# H                -115775.466 eV
# ===============================
#
# Entropy components at T = 1223.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0022806 eV/K        2.790 eV
# S_rot              0.0017391 eV/K        2.127 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0087570 eV/K       10.711 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0127756 eV/K       15.626 eV
# =================================================
#
# Free energy components at T = 1223.15 K and P = 101325.0 Pa:
# =======================
#     H    -115775.466 eV
#  -T*S        -15.626 eV
# -----------------------
#     G    -115791.093 eV
# =======================
# Internal energy components at T = 1223.15 K:
# ===============================
# E_pot            -115781.310 eV
# E_ZPE                  1.464 eV
# Cv_harm (0->T)         3.958 eV
# -------------------------------
# U                -115775.888 eV
# ===============================
#
# Entropy components at T = 1223.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0087570 eV/K       10.711 eV
# -------------------------------------------------
# S                  0.0087570 eV/K       10.711 eV
# =================================================
#
# Free energy components at T = 1223.15 K:
# =======================
#     U    -115775.888 eV
#  -T*S        -10.711 eV
# -----------------------
#     F    -115786.599 eV
# =======================
# Enthalpy components at T = 1223.15 K:
# ===============================
# E_pot            -139227.079 eV
# E_ZPE                  0.694 eV
# Cv_trans (0->T)        0.158 eV
# Cv_rot (0->T)          0.158 eV
# Cv_vib (0->T)          4.096 eV
# (C_v -> C_p)           0.105 eV
# -------------------------------
# H                -139221.868 eV
# ===============================
#
# Entropy components at T = 1223.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0023064 eV/K        2.821 eV
# S_rot              0.0017988 eV/K        2.200 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0096421 eV/K       11.794 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0137461 eV/K       16.814 eV
# =================================================
#
# Free energy components at T = 1223.15 K and P = 101325.0 Pa:
# =======================
#     H    -139221.868 eV
#  -T*S        -16.814 eV
# -----------------------
#     G    -139238.681 eV
# =======================
# Internal energy components at T = 1223.15 K:
# ===============================
# E_pot            -139227.079 eV
# E_ZPE                  0.694 eV
# Cv_harm (0->T)         4.096 eV
# -------------------------------
# U                -139222.289 eV
# ===============================
#
# Entropy components at T = 1223.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0096421 eV/K       11.794 eV
# -------------------------------------------------
# S                  0.0096421 eV/K       11.794 eV
# =================================================
#
# Free energy components at T = 1223.15 K:
# =======================
#     U    -139222.289 eV
#  -T*S        -11.794 eV
# -----------------------
#     F    -139234.083 eV
# =======================
# Enthalpy components at T = 1223.15 K:
# ===============================
# E_pot            -162739.393 eV
# E_ZPE                  0.835 eV
# Cv_trans (0->T)        0.158 eV
# Cv_rot (0->T)          0.158 eV
# Cv_vib (0->T)          4.913 eV
# (C_v -> C_p)           0.105 eV
# -------------------------------
# H                -162733.224 eV
# ===============================
#
# Entropy components at T = 1223.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0023283 eV/K        2.848 eV
# S_rot              0.0018406 eV/K        2.251 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0115151 eV/K       14.085 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0156829 eV/K       19.183 eV
# =================================================
#
# Free energy components at T = 1223.15 K and P = 101325.0 Pa:
# =======================
#     H    -162733.224 eV
#  -T*S        -19.183 eV
# -----------------------
#     G    -162752.406 eV
# =======================
# Internal energy components at T = 1223.15 K:
# ===============================
# E_pot            -162739.393 eV
# E_ZPE                  0.835 eV
# Cv_harm (0->T)         4.913 eV
# -------------------------------
# U                -162733.645 eV
# ===============================
#
# Entropy components at T = 1223.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0115151 eV/K       14.085 eV
# -------------------------------------------------
# S                  0.0115151 eV/K       14.085 eV
# =================================================
#
# Free energy components at T = 1223.15 K:
# =======================
#     U    -162733.645 eV
#  -T*S        -14.085 eV
# -----------------------
#     F    -162747.730 eV
# =======================
# Enthalpy components at T = 1223.15 K:
# ===============================
# E_pot            -186251.475 eV
# E_ZPE                  0.975 eV
# Cv_trans (0->T)        0.158 eV
# Cv_rot (0->T)          0.158 eV
# Cv_vib (0->T)          5.730 eV
# (C_v -> C_p)           0.105 eV
# -------------------------------
# H                -186244.348 eV
# ===============================
#
# Entropy components at T = 1223.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0023471 eV/K        2.871 eV
# S_rot              0.0018801 eV/K        2.300 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0133758 eV/K       16.361 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0176018 eV/K       21.530 eV
# =================================================
#
# Free energy components at T = 1223.15 K and P = 101325.0 Pa:
# =======================
#     H    -186244.348 eV
#  -T*S        -21.530 eV
# -----------------------
#     G    -186265.877 eV
# =======================
# Internal energy components at T = 1223.15 K:
# ===============================
# E_pot            -186251.475 eV
# E_ZPE                  0.975 eV
# Cv_harm (0->T)         5.730 eV
# -------------------------------
# U                -186244.769 eV
# ===============================
#
# Entropy components at T = 1223.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0133758 eV/K       16.361 eV
# -------------------------------------------------
# S                  0.0133758 eV/K       16.361 eV
# =================================================
#
# Free energy components at T = 1223.15 K:
# =======================
#     U    -186244.769 eV
#  -T*S        -16.361 eV
# -----------------------
#     F    -186261.130 eV
# =======================
# Enthalpy components at T = 1223.15 K:
# ===============================
# E_pot            -209763.814 eV
# E_ZPE                  1.120 eV
# Cv_trans (0->T)        0.158 eV
# Cv_rot (0->T)          0.158 eV
# Cv_vib (0->T)          6.544 eV
# (C_v -> C_p)           0.105 eV
# -------------------------------
# H                -209755.729 eV
# ===============================
#
# Entropy components at T = 1223.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0023635 eV/K        2.891 eV
# S_rot              0.0019087 eV/K        2.335 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0151591 eV/K       18.542 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0194302 eV/K       23.766 eV
# =================================================
#
# Free energy components at T = 1223.15 K and P = 101325.0 Pa:
# =======================
#     H    -209755.729 eV
#  -T*S        -23.766 eV
# -----------------------
#     G    -209779.495 eV
# =======================
# Internal energy components at T = 1223.15 K:
# ===============================
# E_pot            -209763.814 eV
# E_ZPE                  1.120 eV
# Cv_harm (0->T)         6.544 eV
# -------------------------------
# U                -209756.151 eV
# ===============================
#
# Entropy components at T = 1223.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0151591 eV/K       18.542 eV
# -------------------------------------------------
# S                  0.0151591 eV/K       18.542 eV
# =================================================
#
# Free energy components at T = 1223.15 K:
# =======================
#     U    -209756.151 eV
#  -T*S        -18.542 eV
# -----------------------
#     F    -209774.693 eV
# =======================
# Enthalpy components at T = 1223.15 K:
# ===============================
# E_pot            -233275.146 eV
# E_ZPE                  1.254 eV
# Cv_trans (0->T)        0.158 eV
# Cv_rot (0->T)          0.158 eV
# Cv_vib (0->T)          7.367 eV
# (C_v -> C_p)           0.105 eV
# -------------------------------
# H                -233266.104 eV
# ===============================
#
# Entropy components at T = 1223.15 K and P = 101325.0 Pa:
# =================================================
#                            S               T*S
# S_trans (1 bar)    0.0023780 eV/K        2.909 eV
# S_rot              0.0019330 eV/K        2.364 eV
# S_elec             0.0000000 eV/K        0.000 eV
# S_vib              0.0172025 eV/K       21.041 eV
# S (1 bar -> P)    -0.0000011 eV/K       -0.001 eV
# -------------------------------------------------
# S                  0.0215124 eV/K       26.313 eV
# =================================================
#
# Free energy components at T = 1223.15 K and P = 101325.0 Pa:
# =======================
#     H    -233266.104 eV
#  -T*S        -26.313 eV
# -----------------------
#     G    -233292.416 eV
# =======================
# Internal energy components at T = 1223.15 K:
# ===============================
# E_pot            -233275.146 eV
# E_ZPE                  1.254 eV
# Cv_harm (0->T)         7.367 eV
# -------------------------------
# U                -233266.525 eV
# ===============================
#
# Entropy components at T = 1223.15 K:
# =================================================
#                            S               T*S
# S_harm             0.0172025 eV/K       21.041 eV
# -------------------------------------------------
# S                  0.0172025 eV/K       21.041 eV
# =================================================
#
# Free energy components at T = 1223.15 K:
# =======================
#     U    -233266.525 eV
#  -T*S        -21.041 eV
# -----------------------
#     F    -233287.566 eV
# =======================

# %%
import pickle
import pandas as pd

# Load the data from pickle files
with open('del_G_Ideal.pkl', 'rb') as file:
    del_G_Ideal = pickle.load(file)

with open('del_G_Ideal_MoCO3.pkl', 'rb') as file:
    del_G_Ideal_MoCO3 = pickle.load(file)

with open('del_G_Harmonic.pkl', 'rb') as file:
    del_G_Harmonic = pickle.load(file)
    
with open('del_G_Harmonic_MoCO3.pkl', 'rb') as file:
    del_G_Harmonic_MoCO3 = pickle.load(file)
    
# Convert the dictionaries to DataFrames
df_del_G_Ideal = pd.DataFrame.from_dict(del_G_Ideal)

df_del_G_Ideal_MoCO3 = pd.DataFrame.from_dict(del_G_Ideal_MoCO3)

df_del_G_Harmonic = pd.DataFrame.from_dict(del_G_Harmonic)

df_del_G_Harmonic_MoCO3 = pd.DataFrame.from_dict(del_G_Harmonic_MoCO3)

# Print the DataFrames

print("del_G_Ideal DataFrame:")
print(df_del_G_Ideal)

print("del_G_Ideal_MoCO3 DataFrame:")
print(df_del_G_Ideal_MoCO3)

print("del_G_Harmonic DataFrame:")
print(df_del_G_Harmonic)

print("del_G_Harmonic_MoCO3 DataFrame:")
print(df_del_G_Harmonic_MoCO3)
# Out:
# del_G_Ideal DataFrame:
#              973.15      1023.15     1123.15     1223.15
# MoS4H2    -39.263047  -46.723339  -61.595266  -76.400707
# Mo2S6H4   -68.580744  -82.530325 -110.332263 -138.004579
# Mo3S8H4  -125.916359 -146.824893 -188.478800 -229.917111
# Mo4S10H4 -166.683507 -194.678016 -250.438475 -305.898054
# Mo5S12   -244.063518 -282.244283 -358.284732 -433.901964
# Mo6S14   -312.155437 -357.492897 -447.781950 -537.563163
# Mo7S16   -374.502451 -426.975965 -531.472391 -635.376407
# Mo8S18   -440.747016 -500.252073 -618.746904 -736.564813
# Mo9S20   -489.468387 -556.297684 -689.376303 -821.693476
# del_G_Ideal_MoCO3 DataFrame:
#              973.15      1023.15     1123.15     1223.15
# MoS4H2    -38.084567  -40.477323  -45.275494  -50.083480
# Mo2S6H4   -66.223785  -70.038293  -77.692718  -85.370125
# Mo3S8H4  -122.380920 -128.086845 -139.519483 -150.965430
# Mo4S10H4 -161.969590 -169.693952 -185.159386 -200.629145
# Mo5S12   -238.171121 -251.014203 -276.685870 -302.315827
# Mo6S14   -305.084560 -320.016801 -349.863316 -379.659799
# Mo7S16   -366.253094 -383.253853 -417.233985 -451.155816
# Mo8S18   -431.319180 -450.283945 -488.188725 -526.026995
# Mo9S20   -478.862072 -500.083540 -542.498352 -584.838431
# del_G_Harmonic DataFrame:
#              973.15      1023.15     1123.15     1223.15
# MoS4H2     32.074337   28.686806   22.017787   15.486119
# Mo2S6H4     7.405875   -2.232068  -21.353347  -40.274139
# Mo3S8H4   -47.356662  -63.821355  -96.530196 -128.952576
# Mo4S10H4  -86.005125 -109.446935 -156.044615 -202.270547
# Mo5S12   -161.467547 -194.997089 -261.677708 -327.864244
# Mo6S14   -228.127836 -268.740517 -349.522628 -429.726031
# Mo7S16   -289.168249 -336.849852 -431.705070 -525.897012
# Mo8S18   -354.402822 -409.064075 -517.813913 -625.815962
# Mo9S20   -402.253869 -464.194644 -587.438835 -709.850715
# del_G_Harmonic_MoCO3 DataFrame:
#              973.15      1023.15     1123.15     1223.15
# MoS4H2     33.252816   34.932822   38.337559   41.803347
# Mo2S6H4     9.762834   10.259963   11.286198   12.360316
# Mo3S8H4   -43.821223  -45.083307  -47.570879  -50.000894
# Mo4S10H4  -81.291207  -84.462871  -90.765525  -97.001638
# Mo5S12   -155.575150 -163.767009 -180.078846 -196.278107
# Mo6S14   -221.056959 -231.264421 -251.603993 -271.822667
# Mo7S16   -280.918893 -293.127740 -317.466664 -341.676421
# Mo8S18   -344.974987 -359.095947 -387.255734 -415.278144
# Mo9S20   -391.647554 -407.980500 -440.560884 -472.995669

# %%
import pickle
import matplotlib.pyplot as plt
SUB = str.maketrans("0123456789", "₀₁₂₃₄₅₆₇₈₉")
# Load data from pickle files
with open('del_G_Ideal.pkl', 'rb') as file:
    del_G_Ideal = pickle.load(file)

with open('del_G_Harmonic.pkl', 'rb') as file:
    del_G_Harmonic = pickle.load(file)

# Generate plot for del_G_Ideal
plt.figure(figsize=(6, 6))
#plt.title("ΔG Ideal")
colors = ['red', 'green', 'blue', 'black']
for i, temp in enumerate(T_CVD):
    cluster_files = list(del_G_Ideal[temp].keys())
    x_values = [cluster_size[temp][cluster_file] for cluster_file in cluster_files]
    y_values = [del_G_Ideal[temp][cluster_file] for cluster_file in cluster_files]
    plt.plot(x_values, y_values, 'o', color=colors[i], linestyle='dashed', label=f"T = {temp} K")
plt.ylabel(r'$\Delta$G$^0$ (kcal/mol)',fontsize=12,fontweight='bold')
plt.xlabel("Cluster Size",fontsize=12,fontweight='bold')
x_ticks = range(1, len(cluster_files) + 1)
x_labels = [f"Mo{str(x).translate(SUB)}" for x in x_ticks]
plt.xticks(x_ticks, x_labels)
plt.legend()

#fig.tight_layout(pad=3.0)

plt.savefig("/home/chesagar/CVD_sagar/reacion_plotting/CVD-manuscript_data/Fig/Nucleation_Ideal_final.jpg", dpi=500)
plt.show()

# Generate plot for del_G_Harmonic
# plt.figure(figsize=(6, 5))
# plt.title("ΔG Harmonic")
# for i, temp in enumerate(T_CVD):
#     cluster_files = list(del_G_Harmonic[temp].keys())
#     x_values = [cluster_size[temp][cluster_file] for cluster_file in cluster_files]
#     y_values = [del_G_Harmonic[temp][cluster_file] for cluster_file in cluster_files]
#     plt.plot(x_values, y_values, 'o', color=colors[i], linestyle='dashed', label=f"T = {temp} K")
# plt.ylabel(r'$\Delta$G$^0$ (kcal/mol)',fontsize=12,fontweight='bold')
# plt.xlabel("Cluster Size",fontsize=12,fontweight='bold')
# plt.xticks(x_ticks, x_labels)
# plt.legend()
# #plt.savefig("del_G_Harmonic_plot.png")
# plt.show()
